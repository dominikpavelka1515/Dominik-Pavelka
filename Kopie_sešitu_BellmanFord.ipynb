# %% [markdown]
# <a href="https://colab.research.google.com/github/dominikpavelka1515/Dominik-Pavelka/blob/main/Kopie_se%C5%A1itu_BellmanFord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install osmnx -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 2.9 MB/s eta 0:00:00

# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt

# ── 1. GRAF Z OSM ──────────────────────────────────────────────────
G = ox.graph_from_place("Velká Chuchle", network_type="bike",simplify=True) # zrusim multigraf

# %%
# ── 2. BELLMAN-FORD OD NULY ────────────────────────────────────────
def bellman_ford(graf, start, cil):
    uzly = list(graf.nodes)
    hrany = [(u, v, d["length"]) for u, v, d in graf.edges(data=True)]

    # Vzdálenosti — na začátku vše nekonečno
    dist = {u: float("inf") for u in uzly}
    dist[start] = 0
    odkud = {u: None for u in uzly}

    # Klíčová myšlenka: opakuj (počet uzlů - 1) krát
    for _ in range(len(uzly) - 1):
        zmenilo_se = False
        for u, v, vaha in hrany:          # projdi VŠECHNY hrany
            if dist[u] + vaha < dist[v]:  # lze zlepšit?
                dist[v] = dist[u] + vaha
                odkud[v] = u
                zmenilo_se = True
        if not zmenilo_se:
            break                         # hotovo dřív — optimalizace

    # Rekonstrukce cesty
    cesta, uzel = [], cil
    while uzel is not None:
        cesta.append(uzel)
        uzel = odkud[uzel]
    cesta.reverse()

    return dist[cil], cesta

# ── 3. SPUŠTĚNÍ ────────────────────────────────────────────────────
# Souřadnice pro Základní škola Velká Chuchle (přibližné)
start_gps = (50.0121581, 14.3822597)
# Souřadnice pro Závodiště Chuchle Arena Praha (přibližné - upraveno pro delší trasu)
cil_gps   = (50.0077142, 14.3891342)

start = ox.nearest_nodes(G, X=start_gps[1], Y=start_gps[0])
cil   = ox.nearest_nodes(G, X=cil_gps[1],   Y=cil_gps[0])

delka, cesta = bellman_ford(G, start, cil)
print(f"Délka: {delka:.0f} m,  uzlů: {len(cesta)}")

# ── 4. VIZUALIZACE ─────────────────────────────────────────────────
fig, ax = ox.plot_graph_route(
    G, cesta,
    route_color="red", route_linewidth=4,
    node_size=0, bgcolor="white",
    show=False, close=False,
)
ax.set_title(f"Bellman-Ford — délka cesty {delka:.0f} m")
plt.tight_layout()
plt.savefig("bellman_ford.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Délka: 972 m,  uzlů: 13

# %%
# Instalace osmnx (pokud ještě není nainstalován)
# %pip install osmnx -q

import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
import folium

# ── 1. GRAF Z OSM ──────────────────────────────────────────────────
G = ox.graph_from_place("Velká Chuchle", network_type="bike", simplify=True) # zrusim multigraf

# ── 2. BELLMAN-FORD OD NULY ────────────────────────────────────────
def bellman_ford(graf, start, cil):
    uzly = list(graf.nodes)
    hrany = [(u, v, d["length"]) for u, v, d in graf.edges(data=True)]

    # Vzdálenosti — na začátku vše nekonečno
    dist = {u: float("inf") for u in uzly}
    dist[start] = 0
    odkud = {u: None for u in uzly}

    # Klíčová myšlenka: opakuj (počet uzlů - 1) krát
    for _ in range(len(uzly) - 1):
        zmenilo_se = False
        for u, v, vaha in hrany:          # projdi VŠECHNY hrany
            if dist[u] + vaha < dist[v]:  # lze zlepšit?
                dist[v] = dist[u] + vaha
                odkud[v] = u
                zmenilo_se = True
        if not zmenilo_se:
            break                         # hotovo dřív — optimalizace

    # Rekonstrukce cesty
    cesta, uzel = [], cil
    while uzel is not None:
        cesta.append(uzel)
        uzel = odkud[uzel]
    cesta.reverse()

    return dist[cil], cesta

# ── 3. SPUŠTĚNÍ ────────────────────────────────────────────────────
# Souřadnice pro Základní škola Velká Chuchle (přibližné)
start_gps = (50.0121581, 14.3822597)
# Souřadnice pro Závodiště Chuchle Arena Praha (přibližné - upraveno pro delší trasu)
cil_gps   = (50.0077142, 14.3891342)

start = ox.nearest_nodes(G, X=start_gps[1], Y=start_gps[0])
cil   = ox.nearest_nodes(G, X=cil_gps[1],   Y=cil_gps[0])

delka, cesta = bellman_ford(G, start, cil)
print(f"Délka: {delka:.0f} m,  uzlů: {len(cesta)}")

# ── 4. VIZUALIZACE ─────────────────────────────────────────────────
fig, ax = ox.plot_graph_route(
    G, cesta,
    route_color="red", route_linewidth=4,
    node_size=0, bgcolor="white",
    show=False, close=False,
)
ax.set_title(f"Bellman-Ford — délka cesty {delka:.0f} m")
plt.tight_layout()
plt.savefig("bellman_ford.png", dpi=150, bbox_inches="tight")
plt.show()

# Cesta pomocí OSMnx
cesta_delka = ox.shortest_path(G, start, cil, weight='length')
cesta_cas   = ox.shortest_path(G, start, cil, weight='travel_time')
delka_cesty = nx.shortest_path_length(G, start, cil, weight='length')
print(f'Cesta je dlouhá {delka_cesty:.2f} metrů.')

ox.plot_graph_routes(
    G,
    routes=[cesta_delka, cesta_cas],
    route_colors=["red", "blue"],
    route_linewidths=[4, 4],
    node_size=0,
    bgcolor="white",
)

# ## Folium - Interaktivní mapa

body_delka = [(G.nodes[n]['y'], G.nodes[n]['x']) for n in cesta_delka]
body_cas   = [(G.nodes[n]['y'], G.nodes[n]['x']) for n in cesta_cas]

mid = body_delka[len(body_delka) // 2]
m = folium.Map(location=mid, zoom_start=15, width="70%")

folium.PolyLine(body_delka, color="red",  weight=4).add_to(m)
folium.PolyLine(body_cas,   color="blue", weight=4).add_to(m)

# start a cíl
folium.Marker(body_cas[0], popup="Kaufland", icon=folium.Icon(color="green")).add_to(m)
folium.Marker(body_cas[-1], popup="Medvědi",  icon=folium.Icon(color="red")).add_to(m)

m.save("cestyKladno.html") # content > sample_data
display(m)

# %%
cesta_delka = ox.shortest_path(G, start, cil, weight='length')
cesta_cas   = ox.shortest_path(G, start, cil, weight='travel_time')
delka_cesty = nx.shortest_path_length(G, start, cil, weight='length')
print(f'Cesta je dlouhá {delka_cesty:.2f} metrů.')

ox.plot_graph_routes(
    G,
    routes=[cesta_delka, cesta_cas],
    route_colors=["red", "blue"],
    route_linewidths=[4, 4],
    node_size=0,
    bgcolor="white",

)
# Out:
# Cesta je dlouhá 972.22 metrů.
# /usr/local/lib/python3.12/dist-packages/osmnx/_validate.py:49: UserWarning: The attribute 'travel_time' is missing or null on some edges.
#   _report_validation(is_valid, valid_msg, warn_msg, err_msg)
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Folium - Interaktivní mapa

# %%
import folium

body_delka = [(G.nodes[n]['y'], G.nodes[n]['x']) for n in cesta_delka]
body_cas   = [(G.nodes[n]['y'], G.nodes[n]['x']) for n in cesta_cas]

mid = body_delka[len(body_delka) // 2]
m = folium.Map(location=mid, zoom_start=15, width="70%")

folium.PolyLine(body_delka, color="red",  weight=4).add_to(m)
folium.PolyLine(body_cas,   color="blue", weight=4).add_to(m)

# start a cíl
folium.Marker(body_cas[0], popup="Kaufland", icon=folium.Icon(color="green")).add_to(m)
folium.Marker(body_cas[-1], popup="Medvědi",  icon=folium.Icon(color="red")).add_to(m)

m.save("cestyKladno.html") # content > sample_data
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90100638b38ee96ec07d7f0da13980b1 {
#                     position: relative;
#                     width: 70.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90100638b38ee96ec07d7f0da13980b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90100638b38ee96ec07d7f0da13980b1 = L.map(
#                 &quot;map_90100638b38ee96ec07d7f0da13980b1&quot;,
#                 {
#                     center: [50.1359594, 14.1095285],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22d22923987c817da105a26ec4bde782 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22d22923987c817da105a26ec4bde782.addTo(map_90100638b38ee96ec07d7f0da13980b1);
#
#
#             var poly_line_36bff176370aea1abc419080adafdad8 = L.polyline(
#                 [[50.1318339, 14.1169132], [50.1311392, 14.1146845], [50.1308285, 14.1138875], [50.1306779, 14.1136733], [50.1306852, 14.113475], [50.1310507, 14.113151], [50.1317016, 14.1126402], [50.1319811, 14.1124166], [50.1321177, 14.1123189], [50.1322873, 14.1123884], [50.1322467, 14.1111068], [50.1332305, 14.1112557], [50.134007, 14.111401], [50.1347048, 14.1115633], [50.1348136, 14.1117693], [50.1349231, 14.1116564], [50.1349243, 14.1115234], [50.1348336, 14.1114152], [50.1352165, 14.1106891], [50.1355478, 14.1101664], [50.1358651, 14.1096714], [50.1359594, 14.1095285], [50.1366652, 14.1084817], [50.1369278, 14.1080805], [50.1383178, 14.1073733], [50.1395499, 14.1087593], [50.1399619, 14.1089911], [50.1410286, 14.1075213], [50.1416801, 14.1067448], [50.1423481, 14.1064279], [50.1432702, 14.1059717], [50.1436572, 14.1056337], [50.1436854, 14.1055903], [50.1444241, 14.1048233], [50.1447759, 14.1058486], [50.1451084, 14.1056101], [50.145415, 14.1053797], [50.1459917, 14.1047576], [50.1469266, 14.1035363], [50.1478282, 14.1027789], [50.1478529, 14.10218], [50.1477434, 14.1018249], [50.1479276, 14.1010095]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_90100638b38ee96ec07d7f0da13980b1);
#
#
#             var poly_line_c43b1df97a966c0c60ed396df177e422 = L.polyline(
#                 [[50.1318339, 14.1169132], [50.1311392, 14.1146845], [50.1308285, 14.1138875], [50.1306779, 14.1136733], [50.1306852, 14.113475], [50.1310507, 14.113151], [50.1317016, 14.1126402], [50.1319811, 14.1124166], [50.1321177, 14.1123189], [50.1322873, 14.1123884], [50.1322467, 14.1111068], [50.1321818, 14.1109389], [50.1352972, 14.1056181], [50.1371244, 14.1025922], [50.1388572, 14.1008615], [50.1393247, 14.1004326], [50.1408055, 14.0990959], [50.1414769, 14.0998661], [50.1417581, 14.1001927], [50.1423153, 14.1010908], [50.1424476, 14.10133], [50.1424775, 14.1013839], [50.1426059, 14.1016161], [50.1433922, 14.1030278], [50.1444241, 14.1048233], [50.1447759, 14.1058486], [50.1451084, 14.1056101], [50.145415, 14.1053797], [50.1459917, 14.1047576], [50.1469266, 14.1035363], [50.1478282, 14.1027789], [50.1478529, 14.10218], [50.1477434, 14.1018249], [50.1479276, 14.1010095]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_90100638b38ee96ec07d7f0da13980b1);
#
#
#             var marker_2f11bb85d2417ae5b36a34352e1e889e = L.marker(
#                 [50.1318339, 14.1169132],
#                 {
# }
#             ).addTo(map_90100638b38ee96ec07d7f0da13980b1);
#
#
#             var icon_66432422efb0f78d595cd69370dedf65 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
